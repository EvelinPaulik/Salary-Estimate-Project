# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_clean.csv')

# %%
df.head()
# Out:
#                                            Job Title  \
# 0                              Senior Data Scientist
# 1                           Marketing Data Scientist
# 2                            Data Analyst, NAV Recon
# 3                             Data Mining Specialist
# 4  Intern, Data Engineer – Digital Strategy and I...
#
#                   Salary Estimate  \
# 0  CA$58k-CA$90k (Glassdoor Est.)
# 1  CA$58k-CA$90k (Glassdoor Est.)
# 2  CA$58k-CA$90k (Glassdoor Est.)
# 3  CA$58k-CA$90k (Glassdoor Est.)
# 4  CA$58k-CA$90k (Glassdoor Est.)
#
#                                      Job Description  Rating  \
# 0  Myplanet is looking for a Senior Data Scientis...     4.6
# 1  Top Hat is looking for a technical Marketing D...     3.5
# 2  Data Analyst, NAV Recon\nConnor, Clark & Lunn ...     4.3
# 3  What we do\nInterested in solving problems, en...     5.0
# 4  EXPERIENCE THE EDGE\n\n\nWe’re one of Canada’s...     4.4
#
#                                 Company Name   Location  Headquarters  \
# 0                              Myplanet\n4.6    Toronto            -1
# 1                               Top Hat\n3.5    Toronto            -1
# 2  Connor, Clark & Lunn Financial Group\n4.3  Vancouver            -1
# 3   Global Spatial Technology Solutions\n5.0  Dartmouth            -1
# 4                       PSP Investments\n4.4   Montreal            -1
#
#                     Size  Founded   Type of ownership  ... Province Age  \
# 0    51 to 200 Employees     2009   Company - Private  ...       ON  11
# 1   201 to 500 Employees     2009   Company - Private  ...       ON  11
# 2   201 to 500 Employees     1982   Company - Private  ...       BC  38
# 3      1 to 50 Employees       -1             Unknown  ...       NS  -1
# 4  501 to 1000 Employees     1999  Other Organization  ...       QC  21
#
#   Python  RStudio  Spark  AWS  Excel   JobSimplified  Seniority DescLength
# 0      1        1      0    0      0  data scientist     senior       4502
# 1      1        1      0    0      0  data scientist         na       3982
# 2      0        1      0    0      0         analyst         na       6532
# 3      1        1      0    0      0              na         na       3632
# 4      1        1      1    0      1   data engineer         na       3112
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Hourly', 'EmployerProvided', 'MinSalary', 'MaxSalary', 'AvgSalary',
#        'CompanyText', 'Province', 'Age', 'Python', 'RStudio', 'Spark', 'AWS',
#        'Excel', 'JobSimplified', 'Seniority', 'DescLength'],
#       dtype='object')

# %%
df.describe()
# Out:
#           Rating  Headquarters      Founded  Competitors  Hourly  \
# count  80.000000          80.0    80.000000         80.0    80.0
# mean    3.456250          -1.0  1462.212500         -1.0     0.0
# std     1.490802           0.0   879.178438          0.0     0.0
# min    -1.000000          -1.0    -1.000000         -1.0     0.0
# 25%     3.400000          -1.0    -1.000000         -1.0     0.0
# 50%     3.700000          -1.0  1985.000000         -1.0     0.0
# 75%     4.125000          -1.0  2004.000000         -1.0     0.0
# max     5.000000          -1.0  2020.000000         -1.0     0.0
#
#        EmployerProvided  MinSalary   MaxSalary  AvgSalary         Age  \
# count              80.0  50.000000   80.000000  50.000000   80.000000
# mean                0.0  66.800000   61.250000  81.800000   27.012500
# std                 0.0  10.887177   46.657247   9.649997   39.291347
# min                 0.0  58.000000    2.000000  74.000000   -1.000000
# 25%                 0.0  58.000000    2.000000  74.000000   -1.000000
# 50%                 0.0  58.000000   90.000000  74.000000   15.000000
# 75%                 0.0  80.000000   94.250000  93.500000   31.750000
# max                 0.0  80.000000  107.000000  93.500000  163.000000
#
#           Python  RStudio      Spark        AWS      Excel    DescLength
# count  80.000000     80.0  80.000000  80.000000  80.000000     80.000000
# mean    0.825000      1.0   0.375000   0.225000   0.450000   3844.325000
# std     0.382364      0.0   0.487177   0.420217   0.500633   1851.094618
# min     0.000000      1.0   0.000000   0.000000   0.000000    703.000000
# 25%     1.000000      1.0   0.000000   0.000000   0.000000   2736.750000
# 50%     1.000000      1.0   0.000000   0.000000   0.000000   3330.500000
# 75%     1.000000      1.0   1.000000   0.000000   1.000000   4679.250000
# max     1.000000      1.0   1.000000   1.000000   1.000000  10104.000000

# %% [markdown]
# ### Graphing Intial Values

# %%
df.Rating.hist()

# %%
df.AvgSalary.hist()

# %%
df.Age.hist()

# %%
df.DescLength.hist()

# %%
df.boxplot(column=['Age', 'AvgSalary', 'Rating'])

# %%
df.boxplot('Rating')

# %% [markdown]
# Boxplot shows high outliers in Age, and a few low outliers for Rating

# %% [markdown]
# ### Correlations between continuous variables:

# %%
corr_cont = df[['Age', 'AvgSalary', 'Rating','DescLength']].corr()
corr_cont
# Out:
#                  Age  AvgSalary    Rating  DescLength
# Age         1.000000  -0.122501  0.141426    0.150383
# AvgSalary  -0.122501   1.000000 -0.354600   -0.175607
# Rating      0.141426  -0.354600  1.000000    0.006436
# DescLength  0.150383  -0.175607  0.006436    1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr_cont, cmap=cmap, vmax=.3, center=0, annot=True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Correlations between categorical variables:

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'CompanyText', 'Province','Python', 'RStudio', 'Spark', 'AWS',
       'Excel', 'JobSimplified', 'Seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print('Graph for %s: total = %d'%(i,len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Location: total = 19
# Graph for Headquarters: total = 1
# Graph for Size: total = 9
# Graph for Type of ownership: total = 11
# Graph for Industry: total = 27
# Graph for Sector: total = 17
# Graph for Revenue: total = 11
# Graph for CompanyText: total = 75
# Graph for Province: total = 8
# Graph for Python: total = 2
# Graph for RStudio: total = 1
# Graph for Spark: total = 2
# Graph for AWS: total = 2
# Graph for Excel: total = 2
# Graph for JobSimplified: total = 4
# Graph for Seniority: total = 3

# %% [markdown]
# Top 10 values for the above graphs that were more clustered:

# %%
for i in df_cat[['Industry','Location', 'CompanyText']].columns:
    cat_num = df_cat[i].value_counts()[:10]
    print('Graph for %s: total = %d'%(i,len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Industry: total = 10
# Graph for Location: total = 10
# Graph for CompanyText: total = 10

# %% [markdown]
# ### Analyzing Salary

# %% [markdown]
# Using pivot tables to analyze salaries based on factors:
# - Province
# - Rating
# - Industry
# - Revenue
# - Python
# - R Studio
# - AWS
# - Excel
# - Description Length
# - Type of Ownership

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Hourly', 'EmployerProvided', 'MinSalary', 'MaxSalary', 'AvgSalary',
#        'CompanyText', 'Province', 'Age', 'Python', 'RStudio', 'Spark', 'AWS',
#        'Excel', 'JobSimplified', 'Seniority', 'DescLength'],
#       dtype='object')

# %%
pd.pivot_table(df, index='JobSimplified', values='AvgSalary')
# Out:
#                 AvgSalary
# JobSimplified
# analyst            83.750
# data engineer      78.875
# data scientist     82.000
# na                 74.000

# %%
pd.pivot_table(df, index=['JobSimplified', 'Seniority'], values='AvgSalary')
# Out:
#                           AvgSalary
# JobSimplified  Seniority
# analyst        na         83.750000
# data engineer  na         78.875000
# data scientist jr         74.000000
#                na         82.914286
#                senior     74.000000
# na             na         74.000000

# %%
pd.pivot_table(df, index=['Province'], values='AvgSalary').sort_values('AvgSalary', ascending=False)
# Out:
#           AvgSalary
# Province
# NL        93.500000
# ON        84.214286
# BC        81.312500
# AB        80.500000
# QC        80.500000
# NB        74.000000
# NS        74.000000
# Unknown   74.000000

# %%
pd.pivot_table(df, index=['Province','JobSimplified'], values='AvgSalary').sort_values('AvgSalary', ascending=False)
# Out:
#                          AvgSalary
# Province JobSimplified
# NL       data scientist  93.500000
# ON       analyst         93.500000
# BC       analyst         83.750000
# QC       data engineer   83.750000
# ON       data scientist  83.236842
# AB       data scientist  80.500000
# BC       data scientist  80.500000
# QC       data scientist  80.500000
# NB       analyst         74.000000
# NS       data scientist  74.000000
#          na              74.000000
# QC       analyst         74.000000
# Unknown  data engineer   74.000000

# %% [markdown]
# Surprisingly the results show Newfoundland (NL) as the province with the highest Data Science salaries. Doing further research, in 2019 Newfoundland jump-started their work in health analytics by investing $3.8 million in a Health Data Lab focused on analytics and artificial intelligence to improve healthcare delivery. This initiative may become the most advanced of its sort in Canada. More information can be found at https://www.canhealth.com/2019/03/01/newfoundland-jump-starts-its-work-in-health-analytics/

# %% [markdown]
# Comparing below only Data Scientist and only Analyst role salaries

# %%
pd.pivot_table(df[df.JobSimplified=='data scientist'], index=['Province','JobSimplified'], values='AvgSalary').sort_values('AvgSalary', ascending=False)
# Out:
#                          AvgSalary
# Province JobSimplified
# NL       data scientist  93.500000
# ON       data scientist  83.236842
# AB       data scientist  80.500000
# BC       data scientist  80.500000
# QC       data scientist  80.500000
# NS       data scientist  74.000000

# %%
pd.pivot_table(df[df.JobSimplified=='analyst'], index=['Province','JobSimplified'], values='AvgSalary').sort_values('AvgSalary', ascending=False)
# Out:
#                         AvgSalary
# Province JobSimplified
# ON       analyst            93.50
# BC       analyst            83.75
# NB       analyst            74.00
# QC       analyst            74.00

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Hourly', 'EmployerProvided', 'MinSalary', 'MaxSalary', 'AvgSalary',
#        'CompanyText', 'Province', 'Age', 'Python', 'RStudio', 'Spark', 'AWS',
#        'Excel', 'JobSimplified', 'Seniority', 'DescLength'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
       'Hourly', 'EmployerProvided', 'Python', 'RStudio', 'Spark', 'AWS', 'Excel', 'AvgSalary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index=i, values='AvgSalary').sort_values('AvgSalary', i, ascending=False))
# Out:
# Rating
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-262-84b8457742aa> in <module>
#       1 for i in df_pivots.columns:
#       2     print(i)
# ----> 3     print(pd.pivot_table(df_pivots, index=i, values='AvgSalary').sort_values('AvgSalary', i, ascending=False))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4972     ):
#    4973         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4974         axis = self._get_axis_number(axis)
#    4975
#    4976         if not isinstance(by, list):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     409             except KeyError:
#     410                 pass
# --> 411         raise ValueError("No axis named {0} for object type {1}".format(axis, cls))
#     412
#     413     @classmethod
#
# ValueError: No axis named Rating for object type <class 'pandas.core.frame.DataFrame'>
