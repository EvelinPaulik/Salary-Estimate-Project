# %%
import import_ipynb
import glassdoor_scraper as gs
import pandas as pd

# Need to use VPN to access US Glassdoor if out of country
path = "C:/Users/Visitor/Desktop/Github/Salary Estimate Project/chromedriver"
df = gs.get_jobs('data scientist', 15, False, path, 15)
# Out:
# importing Jupyter notebook from glassdoor_scraper.ipynb
# x out worked
# Progress: 0/15
# Progress: 1/15
# Progress: 2/15
# Progress: 3/15
# Progress: 4/15
# Progress: 5/15
# Progress: 6/15
# Progress: 7/15
# Progress: 8/15
# Progress: 9/15
# Progress: 10/15
# Progress: 11/15
# Progress: 12/15
# Progress: 13/15
# Progress: 14/15
# Progress: 15/15

# %%
df.head(5)
# Out:
#                                            Job Title  \
# 0                           Marketing Data Scientist
# 1                    Data Scientist, Fraud Analytics
# 2  Intern, Data Engineer – Digital Strategy and I...
# 3                            Data Analyst, NAV Recon
# 4                             Data Mining Specialist
#
#                   Salary Estimate  \
# 0  CA$58k-CA$90k (Glassdoor Est.)
# 1  CA$58k-CA$90k (Glassdoor Est.)
# 2  CA$58k-CA$90k (Glassdoor Est.)
# 3  CA$58k-CA$90k (Glassdoor Est.)
# 4  CA$58k-CA$90k (Glassdoor Est.)
#
#                                      Job Description Rating  \
# 0  Top Hat is looking for a technical Marketing D...    3.5
# 1  Data Scientist Fraud Analytics\n\nFraud Manage...    3.6
# 2  EXPERIENCE THE EDGE\n\n\nWe’re one of Canada’s...    4.4
# 3  Data Analyst, NAV Recon\nConnor, Clark & Lunn ...    4.3
# 4  What we do\nInterested in solving problems, en...    5.0
#
#                                 Company Name   Location  Headquarters  \
# 0                               Top Hat\n3.5    Toronto            -1
# 1                               Interac\n3.6    Toronto            -1
# 2                       PSP Investments\n4.4   Montreal            -1
# 3  Connor, Clark & Lunn Financial Group\n4.3  Vancouver            -1
# 4   Global Spatial Technology Solutions\n5.0  Dartmouth            -1
#
#                     Size Founded   Type of ownership  \
# 0   201 to 500 Employees    2009   Company - Private
# 1   201 to 500 Employees    1984   Company - Private
# 2  501 to 1000 Employees    1999  Other Organization
# 3   201 to 500 Employees    1982   Company - Private
# 4      1 to 50 Employees      -1             Unknown
#
#                                 Industry     Sector  \
# 0                Colleges & Universities  Education
# 1       Financial Transaction Processing    Finance
# 2  Investment Banking & Asset Management    Finance
# 3  Investment Banking & Asset Management    Finance
# 4                                     -1         -1
#
#                       Revenue  Competitors
# 0    $25 to $50 million (USD)           -1
# 1    Unknown / Non-Applicable           -1
# 2    Unknown / Non-Applicable           -1
# 3    $25 to $50 million (USD)           -1
# 4  Less than $1 million (USD)           -1

# %%
df.info

# %%
df.shape

# %%
df.describe
